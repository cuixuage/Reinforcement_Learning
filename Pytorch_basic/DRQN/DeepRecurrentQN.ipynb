# %%
import gym
import math
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
USE_GPU = True

torch.cuda.set_device(3)
# dtype = torch.cuda.FloatTensor # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('using device:', device)
print(torch.cuda.current_device())
# Out:
# using device: cuda
# 3

# %%
TIME_STEP = 1

# 两层的全连接网络
class Net(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        
        self.rnn = nn.LSTM(     # LSTM 效果要比 nn.RNN() 好多了
            input_size=hidden_size,      # 图片每行的数据像素点
            hidden_size=128,     # rnn hidden unit
            num_layers=1,       # 有几层 RNN layers
            batch_first=True,   # input & output 会是以 batch size 为第一维度的特征集 e.g. (batch, time_step, input_size)
        )
        
        self.linear2 = nn.Linear(128, output_size)
        
    def forward(self, x):
        x = F.relu( self.linear1(x))
        
#         print(x.size())
        x = x.view(-1, TIME_STEP, 32)   # reshape x to (batch, time_step, input_size)
#         print(x.size())
        
        r_out, (h_n, h_c) = self.rnn(x, None)   # None 表示 hidden state 会用全0的 state
        # 选取最后一个时间点的 r_out 输出
        # 这里 r_out[:, -1, :] 的值也是 h_n 的值
        x = self.linear2(r_out[:, -1, :])
        
        return x

# %%
class Agent(object):
    def __init__(self, **kwargs):
        for key, value in kwargs.items():
            setattr(self, key, value)
        self.eval_net = Net(self.state_space_dim, 32, self.action_space_dim).to(device)
        self.optimizer = optim.Adam(self.eval_net.parameters(), lr=self.lr)
        self.buffer = []
        self.steps = 0
    def act(self, s0):
        self.steps += 1
        epsi = self.epsi_low + (self.epsi_high-self.epsi_low) * (math.exp(-1.0 * self.steps/self.decay))
        if random.random() < epsi:
            a0 = random.randrange(self.action_space_dim)
        else:
            s0 =  torch.tensor(s0, dtype=torch.float,device=device).view(1,-1)
            a0 = torch.argmax(self.eval_net(s0)).item()
        return a0

    def put(self, *transition):
        if len( self.buffer)==self.capacity:
            self.buffer.pop(0)
        self.buffer.append(transition)
        
    def learn(self):
        if (len(self.buffer)) < self.batch_size:
            return
        
        samples = random.sample( self.buffer, self.batch_size)
        
        s0, a0, r1, s1 = zip(*samples)
        s0 = torch.tensor( s0, dtype=torch.float,device=device)
        a0 = torch.tensor( a0, dtype=torch.long,device=device).view(self.batch_size, -1)
        r1 = torch.tensor( r1, dtype=torch.float,device=device).view(self.batch_size, -1)
        s1 = torch.tensor( s1, dtype=torch.float,device=device)
        
        y_true = r1 + self.gamma * torch.max( self.eval_net(s1).detach(), dim=1)[0].view(self.batch_size, -1)
        y_pred = self.eval_net(s0).gather(1, a0)
        
#         print( y_pred)
#         print(y_true)
        
        loss_fn = nn.MSELoss()
        loss = loss_fn(y_pred, y_true)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
    def plot(self, score, mean):
        from IPython import display
        display.clear_output(wait=True)
        display.display(plt.gcf())
        plt.figure(figsize=(20,10))
        plt.clf()
        plt.title('Training...')
        plt.xlabel('Episode')
        plt.ylabel('Duration')
        plt.plot(score)
        plt.plot(mean)
        plt.text(len(score)-1, score[-1], str(score[-1]))
        plt.text(len(mean)-1, mean[-1], str(mean[-1]))

# %%
env = gym.make('CartPole-v0')

params = {
    'gamma': 0.8,
    'epsi_high': 0.9,
    'epsi_low': 0.05,
    'decay': 200, 
    'lr': 0.001,
    'capacity': 10000,
    'batch_size': 64,
    'state_space_dim': env.observation_space.shape[0],
    'action_space_dim': env.action_space.n   
}
agent = Agent(**params)

score = []
mean = []

#FIXME:  没有间隔固定步数更新y_true的参数
for episode in range(1000):
    s0 = env.reset()
    total_reward = 1
    while True:
        env.render()
        a0 = agent.act(s0)
        s1, r1, done, _ = env.step(a0)
        
        if done:
            r1 = -1
            
        agent.put(s0, a0, r1, s1)#加入到memory中
        
        if done:
            break

        total_reward += r1
        s0 = s1
        agent.learn() #minibatch训练NN
    
    #一轮模拟结束
#     if(len(score)%10==0):
    score.append(total_reward)
    mean.append( sum(score[-100:])/100)
    agent.plot(score, mean)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2a7362a5193b> in <module>()
#      22     total_reward = 1
#      23     while True:
# ---> 24         env.render()
#      25         a0 = agent.act(s0)
#      26         s1, r1, done, _ = env.step(a0)
#
# /home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/gym/core.py in render(self, mode)
#     282
#     283     def render(self, mode='human'):
# --> 284         return self.env.render(mode)
#     285
#     286     def close(self):
#
# /home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     135         self.poletrans.set_rotation(-x[2])
#     136
# --> 137         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     138
#     139     def close(self):
#
# /home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#      86         self.transform.enable()
#      87         for geom in self.geoms:
# ---> 88             geom.render()
#      89         for geom in self.onetime_geoms:
#      90             geom.render()
#
# /home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render(self)
#     156         for attr in reversed(self.attrs):
#     157             attr.enable()
# --> 158         self.render1()
#     159         for attr in self.attrs:
#     160             attr.disable()
#
# /home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render1(self)
#     229         else: glBegin(GL_TRIANGLES)
#     230         for p in self.v:
# --> 231             glVertex3f(p[0], p[1],0)  # draw each vertex
#     232         glEnd()
#     233
#
# /home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      83     pass
#      84
# ---> 85 def errcheck(result, func, arguments):
#      86     if _debug_gl_trace:
#      87         try:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 175, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2908, in run_cell
#     self.events.trigger('post_execute')
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/IPython/core/events.py", line 74, in trigger
#     func(*args, **kwargs)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/pyplot.py", line 149, in post_execute
#     draw_all()
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py", line 150, in draw_all
#     f_mgr.canvas.draw_idle()
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 2032, in draw_idle
#     self.draw(*args, **kwargs)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py", line 464, in draw
#     self.figure.draw(self.renderer)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/artist.py", line 63, in draw_wrapper
#     draw(artist, renderer, *args, **kwargs)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/figure.py", line 1143, in draw
#     renderer, self, dsu, self.suppressComposite)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/image.py", line 139, in _draw_list_compositing_images
#     a.draw(renderer)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/artist.py", line 63, in draw_wrapper
#     draw(artist, renderer, *args, **kwargs)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/axes/_base.py", line 2409, in draw
#     mimage._draw_list_compositing_images(renderer, self, dsu)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/image.py", line 139, in _draw_list_compositing_images
#     a.draw(renderer)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/artist.py", line 63, in draw_wrapper
#     draw(artist, renderer, *args, **kwargs)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/axis.py", line 1138, in draw
#     renderer)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/axis.py", line 1078, in _get_tick_bboxes
#     extent = tick.label1.get_window_extent(renderer)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/text.py", line 967, in get_window_extent
#     bbox, info, descent = self._get_layout(self._renderer)
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/matplotlib/text.py", line 413, in _get_layout
#     xmin, xmax = txs.min(), txs.max()
#
#   File "/home/cuixuange/CS231N_ENV/lib/python3.6/site-packages/numpy/core/_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
#
# KeyboardInterrupt
